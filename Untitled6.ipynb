# %%
import pandas as pd
data={
    "month":['jun','feb','mar','april','may','june'],
    "electronics":[60,30,50,90,58,89],
    "browsary":[30,40,80,50,70,58],
    "clotha":[30,50,80,70,60,20]
    }
df=pd.DataFrame(data)

total=df['total']=df[['electronics', "browsary","clotha"]].sum(axis=1)
print(df)
df.plot(kind='line',x='month')
df.plot(kind='bar',x='month',y='electronics')
# Out:
#    month  electronics  browsary  clotha  total
# 0    jun           60        30      30    120
# 1    feb           30        40      50    120
# 2    mar           50        80      80    210
# 3  april           90        50      70    210
# 4    may           58        70      60    188
# 5   june           89        58      20    167
# <Axes: xlabel='month'>

# %%
total=df[['electronics','browsary','clotha']].sum()
total
mylables=['electronics','browsary','clotha']
plt.pie(total,lable=mylables)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 4
#       2 total
#       3 mylables=['electronics','browsary','clotha']
# ----> 4 plt.pie(total,lable=mylables)
#
# TypeError: pie() got an unexpected keyword argument 'lable'

# %%
print(total)
# Out:
# 0    120
# 1    120
# 2    210
# 3    210
# 4    188
# 5    167
# dtype: int64
