# %%
import matplotlib.pyplot as plt
import numpy as np
student=np.array(["john","manoj","ramesh"])
percentage=np.array(["60%","90","85",])
plt.bar(student,percentage)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
game=np.array(["cricket","vollyball","hacky","others"])
labels=np.array(["30%","20","25","25"])
plt.pie(game,labels=mylabels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       3 game=np.array(["cricket","vollyball","hacky","others"])
#       4 labels=np.array(["30%","20","25","25"])
# ----> 5 plt.pie(game,labels=mylabels)
#       6 plt.show()
#
# NameError: name 'mylabels' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
month=np.array(["june","julay","augest"])
rain=np.array(["60%","90","85",])
plt.plot(month,rain)
plt.show()

# %% [markdown]
# #poting pandas dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('Downloads/heart.csv')
print(df)
df.plot(kind='scatter',x='age',y='oldpeak')
df.plot(kind='line',x='age',y='fbs')
df.plot(kind='hist',x='age',y='chol')
df.plot(kind='bar',x='age',y='fbs')
df.plot(kind='pie',x='cp',y='sex')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('Downloads/heart.csv')
print(df)
df.plot(kind='bar',x='sex',y='age')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([10,20,30,40,50])
y=np.array([10,20,30,40,50])
plt.plot(x,y)

# %%
df.plot(kind='hist',x='age',y='chol')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np
import matplotlib.pyplot as plt
name=np.array(['rohan','charan','goutham'])
age=np.array([10,20,30])
plt.plot(name,age)
plt.show()

# %%
a=int(input("enter any number"))
b=int(input("enter any number"))
c=int(input("enter any number"))
if a>b and a>c:
    print("a is bigg")
elif b>a and b>c:
    print("b is bigg")
else:
    
    print("c is grater")
# Out:
# enter any number 10
# enter any number 80
# enter any number 30
# b is bigg

# %%
n=int(input("enter any number"))
if n%2==0:
    print("even number")
else:
    print("odd")
# Out:
# enter any number 4
# even number

# %%
a=[(10,20,50,40,50)]
print("the length of the arry",a.lenth())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 a=[(10,20,50,40,50)]
# ----> 2 print("the length of the arry",a.lenth())
#
# AttributeError: 'list' object has no attribute 'lenth'

# %%
import numpy as np
a=np.array([10,20,30,50,90,30])
print(a.shape)
print(b.reshape(3,2))
# Out:
# (6,)
# [[10 20]
#  [30 50]
#  [90 30]]

# %%
import pandas as pd
data={
    "bike":[20,30,50,60,90]
}
df=pd.DataFrame(data)
print(data)
a=df.sum(axis=1)
print(a)
# Out:
# {'bike': [20, 30, 50, 60, 90]}
# 0    20
# 1    30
# 2    50
# 3    60
# 4    90
# dtype: int64

# %%
import numpy as array
a=np.array([10,50,10,40,30])
print(a.sum())
print(a.mean())
print(a.min())
print(a.max())
# Out:
# 140
# 28.0
# 10
# 50

# %%
a=[1,30,50,44,98,65]
b=filter(lambda x:x%2==0,a)
print(list(b))
# Out:
# [30, 50, 44, 98]
