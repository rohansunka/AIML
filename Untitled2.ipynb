# %%
import matplotlib.pyplot as plt
import numpy as np
a=np.array([10,20])
plt.plot(a)

# %%
import matplotlib.pyplot as plt
import numpy as np
a=np.array([10,90,20,50])
mylayble=["rohan","manoj","sharana","ayan"]
plt.pie(a,'labele=mylayble')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       3 a=np.array([10,90,20,50])
#       4 mylayble=["rohan","manoj","sharana","ayan"]
# ----> 5 plt.pie(a,'layble=mylayble')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3558, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3535 @_copy_docstring_and_deprecators(Axes.pie)
#    3536 def pie(
#    3537     x: ArrayLike,
#    (...)
#    3556     data=None,
#    3557 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3558     return gca().pie(
#    3559         x,
#    3560         explode=explode,
#    3561         labels=labels,
#    3562         colors=colors,
#    3563         autopct=autopct,
# ...
